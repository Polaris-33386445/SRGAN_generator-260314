# %%
import torch
from utils import *
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# %%
# Data parameters
srgan_checkpoint = "../checkpoint_srgan.pth.tar"
HR_image_path = '../benchmark/B100/HR/16077.png'
LR_image_path = '../benchmark/B100/LR_bicubic/X4/16077x4.png'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Load models
srgan_generator = torch.load(srgan_checkpoint)['generator'].to(device)
srgan_generator.eval()
# Out:
# Generator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (1): PReLU(num_parameters=1)
#   )
#   (res_blocks): ModuleList(
#     (0-15): 16 x Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (upsample_blocks): ModuleList(
#     (0-1): 2 x Sequential(
#       (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): PixelShuffle(upscale_factor=2)
#       (2): PReLU(num_parameters=1)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 3, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (1): Tanh()
#   )
# )

# %%
hr_img = Image.open(HR_image_path, mode="r")
hr_img = hr_img.convert('RGB')
lr_img = Image.open(LR_image_path, mode="r")
lr_img = lr_img.convert('RGB')

# %%
# Bicubic Upsampling
bicubic_img = lr_img.resize((hr_img.width, hr_img.height), Image.BICUBIC)
# Super-resolution (SR) with SRGAN
sr_img_srgan = srgan_generator(convert_image(lr_img, source='pil', target='[0, 1]', device=device).unsqueeze(0).to(device))
sr_img_srgan = sr_img_srgan.squeeze(0).detach()
sr_img_srgan = convert_image(sr_img_srgan, source='[-1, 1]', target='pil', device=device)

# %%
# Visualization
plt.figure('Bicubic')
plt.imshow(bicubic_img)
plt.axis('off')
plt.title('Bicubic')
plt.figure('SRGAN')
plt.imshow(sr_img_srgan)
plt.axis('off')
plt.title('SRGAN')
plt.figure('Original HR')
plt.imshow(hr_img)
plt.axis('off')
plt.title('Original HR')
plt.show()
